# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'real-life-violence-situations-dataset:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F176381%2F397693%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240827%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240827T110626Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading real-life-violence-situations-dataset, 3847870446 bytes compressed
# [==================================================] 3847870446 bytes downloaded
# Downloaded and uncompressed: real-life-violence-situations-dataset
# Data source import complete.

# %% [markdown]
# # Downloading/Importing Dependencies/Libraries

# %%
# !pip install git+https://github.com/Ahmaddimran/pytorchvideo.git@test
# Out:
# Collecting git+https://github.com/Ahmaddimran/pytorchvideo.git@test
#   Cloning https://github.com/Ahmaddimran/pytorchvideo.git (to revision test) to /tmp/pip-req-build-rlgcpffe
#   Running command git clone --filter=blob:none --quiet https://github.com/Ahmaddimran/pytorchvideo.git /tmp/pip-req-build-rlgcpffe
#   Running command git checkout -b test --track origin/test
#   Switched to a new branch 'test'
#   Branch 'test' set up to track remote branch 'test' from 'origin'.
#   Resolved https://github.com/Ahmaddimran/pytorchvideo.git to commit a4d237e94290a6221c84b7eaeec639cebbdf37be
#   Preparing metadata (setup.py) ... done
# Collecting fvcore (from pytorchvideo==0.1.5)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo==0.1.5)
#   Downloading av-12.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting parameterized (from pytorchvideo==0.1.5)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo==0.1.5)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pytorchvideo==0.1.5) (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (1.26.4)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo==0.1.5)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (4.66.5)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo==0.1.5) (0.9.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from iopath->pytorchvideo==0.1.5) (4.12.2)
# Collecting portalocker (from iopath->pytorchvideo==0.1.5)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Downloading av-12.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 41.9 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=201352 sha256=3852d9c799fe2d0c9e3fa204662330a1ed680525cd36daf8f10d63af85f22ab1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7ear3om2/wheels/31/d3/eb/c4e3f11c451886ba3c84ef70f6658a6e555404e2c501b86603
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61395 sha256=a256d724fc0e8e3d67d7bd4dcbfc4cd201e24a37db03a6a08f0260f851036dee
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31529 sha256=261b8283a5b6811bebe61ef78c48181696d9ef4edb8c15bf6a368eb74f188d52
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, portalocker, parameterized, av, iopath, fvcore, pytorchvideo
# Successfully installed av-12.3.0 fvcore-0.1.5.post20221221 iopath-0.1.10 parameterized-0.9.0 portalocker-2.10.1 pytorchvideo-0.1.5 yacs-0.1.8

# %%
# !pip install pytorch-lightning
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.4.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.12.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (71.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics>=0.7.0->pytorch-lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 37.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Downloading torchmetrics-1.4.1-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.2/866.2 kB 32.8 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.11.6 pytorch-lightning-2.4.0 torchmetrics-1.4.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from glob import glob
from PIL import Image
import cv2
import os

from sklearn.metrics import classification_report
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split,KFold,GroupShuffleSplit,GroupKFold,LeaveOneGroupOut

import pytorch_lightning
import pytorchvideo
from pytorch_lightning import seed_everything, LightningModule, Trainer
import torch.nn as nn
import torch
from torch.utils.data.dataloader import DataLoader
from pytorch_lightning.callbacks import EarlyStopping,ModelCheckpoint,LearningRateMonitor
print(pytorch_lightning.__version__)
from torch.optim.lr_scheduler import CyclicLR, ReduceLROnPlateau,CosineAnnealingWarmRestarts,OneCycleLR,CosineAnnealingLR
import torchvision

from torch.utils.data import DataLoader, Dataset,ConcatDataset,default_collate
from torchmetrics import MeanAbsoluteError
from torchaudio import transforms as TA
import torchmetrics
# Out:
# 2.4.0

# %% [markdown]
# # Importing Data

# %%
# Joins Dataset Path with Input Path
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_481.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_917.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_31.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_700.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_109.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_935.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_436.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_32.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_807.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_581.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_148.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_46.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_550.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_773.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_624.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_301.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_579.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_765.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_23.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_986.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_621.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_224.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_520.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_251.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_657.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_3.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_123.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_336.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_106.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_547.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_626.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_191.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_568.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_485.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_551.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_969.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_840.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_438.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_934.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_146.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_114.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_762.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_870.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_777.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_261.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_841.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_866.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_467.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_609.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_375.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_951.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_161.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_803.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_988.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_141.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_842.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_718.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_628.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_356.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_387.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_105.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_806.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_883.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_555.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_761.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_923.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_825.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_535.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_625.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_843.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_528.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_204.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_952.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_317.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_531.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_339.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_910.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_496.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_899.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_407.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_152.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_379.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_135.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_683.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_552.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_990.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_690.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_778.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_366.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_211.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_512.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_796.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_124.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_51.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_737.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_24.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_255.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_349.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_33.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_560.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_605.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_860.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_679.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_851.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_291.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_145.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_811.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_714.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_448.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_746.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_14.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_352.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_182.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_329.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_585.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_562.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_289.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_122.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_713.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_741.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_424.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_527.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_911.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_728.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_707.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_269.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_868.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_601.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_226.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_776.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_163.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_651.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_837.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_747.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_214.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_836.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_234.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_928.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_167.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_816.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_212.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_794.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_738.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_654.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_195.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_443.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_566.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_133.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_244.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_279.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_66.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_940.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_454.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_293.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_582.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_394.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_371.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_687.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_22.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_65.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_792.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_10.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_873.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_780.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_223.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_750.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_756.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_343.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_154.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_681.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_881.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_509.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_529.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_943.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_502.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_312.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_144.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_517.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_594.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_949.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_697.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_715.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_63.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_483.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_254.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_897.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_641.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_985.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_460.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_668.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_129.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_577.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_85.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_441.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_795.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_824.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_384.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_218.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_142.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_998.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_249.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_480.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_417.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_595.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_856.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_977.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_947.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_5.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_176.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_15.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_561.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_823.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_915.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_472.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_766.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_808.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_617.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_54.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_38.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_340.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_732.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_955.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_200.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_410.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_557.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_730.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_210.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_541.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_920.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_877.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_678.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_303.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_282.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_976.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_402.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_830.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_229.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_731.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_243.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_422.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_227.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_858.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_941.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_945.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_975.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_455.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_360.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_659.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_758.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_245.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_37.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_898.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_821.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_139.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_710.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_961.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_904.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_886.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_580.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_950.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_470.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_960.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_648.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_929.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_693.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_418.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_60.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_754.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_453.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_185.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_101.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_488.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_432.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_984.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_987.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_252.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_25.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_399.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_655.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_642.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_324.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_931.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_972.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_155.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_503.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_451.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_1.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_265.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_764.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_231.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_978.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_426.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_466.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_966.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_854.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_637.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_620.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_196.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_819.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_11.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_705.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_110.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_256.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_283.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_433.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_694.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_72.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_228.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_187.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_308.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_954.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_686.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_497.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_611.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_327.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_544.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_464.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_281.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_822.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_62.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_832.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_804.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_370.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_469.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_543.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_149.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_711.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_498.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_69.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_891.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_286.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_896.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_857.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_525.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_996.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_608.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_901.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_844.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_368.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_198.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_653.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_77.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_400.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_373.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_73.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_593.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_583.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_974.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_884.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_938.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_415.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_266.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_330.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_924.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_477.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_540.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_672.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_220.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_332.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_606.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_420.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_9.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_545.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_553.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_294.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_892.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_47.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_437.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_749.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_633.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_953.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_597.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_748.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_246.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_948.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_91.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_855.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_956.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_958.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_150.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_629.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_734.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_298.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_164.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_392.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_695.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_479.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_889.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_944.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_408.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_381.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_742.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_523.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_262.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_612.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_319.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_913.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_499.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_957.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_964.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_729.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_168.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_80.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_81.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_363.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_542.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_755.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_40.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_906.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_751.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_413.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_119.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_173.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_639.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_793.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_775.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_389.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_572.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_92.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_197.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_434.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_640.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_334.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_649.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_971.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_8.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_598.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_325.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_882.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_462.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_348.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_457.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_103.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_862.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_425.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_505.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_521.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_722.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_358.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_890.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_192.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_67.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_829.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_721.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_706.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_102.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_671.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_726.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_288.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_112.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_365.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_27.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_770.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_677.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_603.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_636.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_689.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_518.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_138.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_516.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_74.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_484.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_970.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_160.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_297.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_201.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_724.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_926.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_699.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_549.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_429.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_740.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_514.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_177.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_131.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_6.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_117.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_768.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_848.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_789.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_18.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_513.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_688.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_357.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_322.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_634.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_116.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_175.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_708.mp4
# /kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/V_965.mp4
# ...
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_129.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_313.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_136.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_417.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_24.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_258.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_792.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_825.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_358.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_116.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_999.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_87.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_58.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_293.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_272.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_656.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_562.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_70.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_894.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_427.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_710.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_912.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_109.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_790.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_137.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_42.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_822.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_4.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_214.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_397.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_232.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_877.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_561.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_363.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_501.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_108.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_965.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_5.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_541.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_366.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_354.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_14.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_644.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_752.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_406.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_63.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_962.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_883.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_658.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_340.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_811.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_478.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_869.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_841.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_458.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_956.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_492.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_522.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_778.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_995.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_153.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_218.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_786.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_78.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_52.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_881.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_631.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_286.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_311.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_969.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_166.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_44.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_652.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_120.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_592.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_468.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_441.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_148.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_95.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_250.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_528.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_385.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_643.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_601.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_600.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_393.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_722.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_603.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_439.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_469.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_647.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_188.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_907.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_481.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_831.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_368.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_556.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_539.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_901.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_97.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_271.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_930.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_336.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_616.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_235.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_238.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_442.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_466.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_437.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_520.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_741.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_734.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_85.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_677.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_871.avi
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_104.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_567.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_265.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_123.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_640.mp4
# /kaggle/input/real-life-violence-situations-dataset/real life violence situations/Real Life Violence Dataset/NonViolence/NV_241.mp4

# %%
# Retrieves List of All path of video ending with .mp4
non_vio_vid_list = glob('/kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/NonViolence/*.mp4')
vio_vid_list = glob('/kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/Violence/*.mp4')
# Produces a label list with label 0 for the number of Non Violence Video List length and vice versa
label = [0] * len(non_vio_vid_list) + [1] * len(vio_vid_list)
# Creates a DataFrame a zip function that maps the concatenated list to its corresponding label
df = pd.DataFrame(zip(non_vio_vid_list + vio_vid_list, label), columns = ['Videos', 'Labels'])

# %%
df.head()
# Out:
#                                               Videos  Labels
# 0  /kaggle/input/real-life-violence-situations-da...       0
# 1  /kaggle/input/real-life-violence-situations-da...       0
# 2  /kaggle/input/real-life-violence-situations-da...       0
# 3  /kaggle/input/real-life-violence-situations-da...       0
# 4  /kaggle/input/real-life-violence-situations-da...       0

# %%
print(df['Labels'].dtype)
print(df['Videos'].dtype)
# Out:
# int64
# object

# %%
train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 42, stratify = df['Labels'])
test_df, val_df = train_test_split(test_df, test_size = 0.6, random_state = 42, stratify = test_df['Labels'])

# %%
train_df['Labels'].value_counts(normalize = True)
# Out:
# Labels
# 1    0.512821
# 0    0.487179
# Name: proportion, dtype: float64

# %%
test_df['Labels'].value_counts(normalize = True)
# Out:
# Labels
# 1    0.512821
# 0    0.487179
# Name: proportion, dtype: float64

# %%
val_df['Labels'].value_counts(normalize = True)
# The Dataset isn't skewed
# Out:
# Labels
# 1    0.510638
# 0    0.489362
# Name: proportion, dtype: float64

# %% [markdown]
# # Video Transformations

# %% [markdown]
# ## Importing Tranformations

# %%
from pytorchvideo.data import LabeledVideoDataset, Kinetics, make_clip_sampler, labeled_video_dataset

from pytorchvideo.transforms import (ApplyTransformToKey, Normalize,UniformTemporalSubsample)

from torchvision.transforms import Compose, Lambda, RandomCrop, RandomHorizontalFlip, Resize

from torchvision.transforms._transforms_video import CenterCropVideo, NormalizeVideo

from torchvision.transforms import ColorJitter,RandomAdjustSharpness,RandomAutocontrast
from torchvision.transforms import Compose, Resize, ToTensor

from time import sleep
import torchvision.models as models
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %% [markdown]
# ## Transformation Pipeline

# %%
video_samples = 20
img_size = 224

# %%
transform = Compose(
    [
        ApplyTransformToKey(key = "video", transform = Compose([Resize((256,256)) ,UniformTemporalSubsample(video_samples)
                                                               ,Lambda(lambda x: x/255.0)
                                                               ,Normalize((0.45,0.45,0.45), (0.255,0.255,0.255))
                                                               #,RandomShortSideScale(min_size = img_size + 16, max_size = img_size +32)
                                                               #,CenterCropVideo(img_size)
                                                               ,RandomHorizontalFlip(0.5)]))
    ]
)

# %% [markdown]
# ## DataLoaders

# %%
video_dur = 3
clipmode = 'random'

# %%
train_obj = labeled_video_dataset(train_df, clip_sampler = make_clip_sampler(clipmode, video_dur),
                                  transform = transform, decode_audio = False)
train_dl = DataLoader(train_obj, batch_size = 16, num_workers = 1)

# %%
val_obj = labeled_video_dataset(val_df, clip_sampler = make_clip_sampler(clipmode, video_dur),
                                  transform = transform, decode_audio = False)
val_dl = DataLoader(val_obj, batch_size = 16, num_workers = 1)

# %%
test_obj = labeled_video_dataset(train_df, clip_sampler = make_clip_sampler(clipmode, video_dur),
                                  transform = transform, decode_audio = False)
test_dl = DataLoader(test_obj, batch_size = 16, num_workers = 1)

# %%
batch = next(iter(val_dl))

# %%
print(f'Video Batch Size {batch["video"].shape}')
print(f'Label Batch Size {batch["label"].shape}')
print(f'Aug Index Batch Size {batch["aug_index"].shape}')
print(f'Video Index Batch Size {batch["video_index"].shape}')
print(f'Clip Index Batch Size {batch["clip_index"].shape}')
# Out:
# Video Batch Size torch.Size([16, 3, 20, 256, 256])
# Label Batch Size torch.Size([16, 1])
# Aug Index Batch Size torch.Size([16])
# Video Index Batch Size torch.Size([16])
# Clip Index Batch Size torch.Size([16])

# %% [markdown]
# # Modelling

# %%
video_detection_model = torch.hub.load('facebookresearch/pytorchvideo', 'efficient_x3d_s', pretrained = True)
# Out:
# Downloading: "https://github.com/facebookresearch/pytorchvideo/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/efficient_x3d_s_original_form.pyth" to /root/.cache/torch/hub/checkpoints/efficient_x3d_s_original_form.pyth
# 100%|██████████| 14.8M/14.8M [00:01<00:00, 8.94MB/s]

# %%
class dModel(LightningModule):

    def __init__(self, model, batch_size, transform):
        super().__init__()

        self.video_model = model
        self.silu = nn.SiLU()
        self.linear = nn.Linear(400, 1)

        self.lr = 1e-3
        self.numworker = 0
        self.batch_size = batch_size

        self.metric = torchmetrics.Accuracy(task='binary', threshold=0.5)
        self.loss_fn = nn.BCEWithLogitsLoss()

        self.train_step_outputs = []
        self.validation_step_outputs = []
        self.test_step_outputs = []

        self.video_duration = 3
        self.clipmode = 'random'
        self.video_transform = transform

    def forward(self, batch):
        x = self.video_model(batch)
        x = self.silu(x)
        x = self.linear(x)
        return x

    def configure_optimizers(self):
        opt = torch.optim.AdamW(params=self.parameters(), lr=self.lr)
        scheduler = CosineAnnealingLR(opt, T_max=6, eta_min=1e-6)
        return {"optimizer": opt, "lr_scheduler": scheduler}

    def training_step(self, batch, batch_idx):
        video, label = batch['video'], batch['label']
        pred = self(video)
        loss = self.loss_fn(pred, label)
        acc = self.metric(pred.sigmoid(), label.int())
        self.train_step_outputs.append({'loss': loss, 'metric': acc})
        self.log('train_loss', loss, on_step=False, on_epoch=True, batch_size = self.batch_size,prog_bar=True)
        self.log('train_acc', acc, on_step=False, on_epoch=True, batch_size = self.batch_size,prog_bar=True)
        return {'loss': loss, 'metric': acc}

    def train_dataloader(self):
        dataset = labeled_video_dataset(
            train_df,
            clip_sampler=make_clip_sampler(self.clipmode, self.video_duration),
            transform=self.video_transform,
            decode_audio=False
        )
        return DataLoader(dataset, batch_size=self.batch_size, num_workers=self.numworker, pin_memory= False)

    def on_train_epoch_end(self):
        if self.train_step_outputs:
            avg_loss = torch.stack([x['loss'] for x in self.train_step_outputs]).mean()
            avg_metric = torch.stack([x['metric'] for x in self.train_step_outputs]).mean()
        else:
            avg_loss = torch.tensor(0.0)
            avg_metric = torch.tensor(0.0)

        self.log('avg_train_loss', avg_loss, prog_bar=True, batch_size = self.batch_size,rank_zero_only=True)
        self.log('avg_train_acc', avg_metric, prog_bar=True, batch_size = self.batch_size,rank_zero_only=True)
        print(f'Epoch {self.current_epoch} - Loss: {avg_loss:.2f}, Accuracy: {avg_metric:.2f}')
        self.train_step_outputs.clear()  # Clear the list after logging

    def val_dataloader(self):
        dataset = labeled_video_dataset(
            val_df,
            clip_sampler=make_clip_sampler(self.clipmode, self.video_duration),
            transform=self.video_transform,
            decode_audio=False
        )
        return DataLoader(dataset, batch_size=self.batch_size, num_workers=self.numworker, pin_memory=False)

    def validation_step(self, batch, batch_idx):
        video, label = batch['video'], batch['label']
        out = self(video)
        loss = self.loss_fn(out, label)
        metric = self.metric(out.sigmoid(), label.int())
        self.validation_step_outputs.append({'loss': loss, 'metric': metric})
        self.log('val_loss', loss, on_step=False, on_epoch=True, batch_size = self.batch_size,prog_bar=True)
        self.log('val_acc', metric, on_step=False, on_epoch=True, batch_size = self.batch_size,prog_bar=True)
        return {'loss': loss, 'metric': metric}

    def on_validation_epoch_end(self):
        if self.validation_step_outputs:
            avg_loss = torch.stack([x['loss'] for x in self.validation_step_outputs]).mean()
            avg_metric = torch.stack([x['metric'] for x in self.validation_step_outputs]).mean()
        else:
            avg_loss = torch.tensor(0.0)
            avg_metric = torch.tensor(0.0)

        self.log('avg_val_loss', avg_loss, prog_bar=True, batch_size = self.batch_size,rank_zero_only=True)
        self.log('avg_val_acc', avg_metric, prog_bar=True, batch_size = self.batch_size,rank_zero_only=True)
        print(f'Validation - Loss: {avg_loss:.2f}, Accuracy: {avg_metric:.2f}')
        self.validation_step_outputs.clear()  # Clear the list after logging

    def test_dataloader(self):
        dataset = labeled_video_dataset(
            test_df,
            clip_sampler=make_clip_sampler(self.clipmode, self.video_duration),
            transform=self.video_transform,
            decode_audio=False
        )
        return DataLoader(dataset, batch_size=self.batch_size, num_workers=self.numworker, pin_memory=False)

    def test_step(self, batch, batch_idx):
        video, label = batch['video'], batch['label']
        out = self(video)
        self.test_step_outputs.append({'label': label.detach(), 'pred': out.detach()})
        return {'label': label.detach(), 'pred': out.detach()}

    def on_test_epoch_end(self):
        if self.test_step_outputs:
            labels = torch.cat([x['label'] for x in self.test_step_outputs]).cpu().numpy()
            preds = torch.cat([x['pred'] for x in self.test_step_outputs]).cpu().numpy()
            preds = np.where(preds > 0.5, 1, 0)
            print(classification_report(labels, preds))
        self.test_step_outputs.clear()  # Clear the list after logging

# %%
model = dModel(video_detection_model, 8, transform)
seed_everything(42, workers=True)
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42
# 42

# %%
trainer = Trainer( accelerator = 'auto', max_epochs = 10,
                 enable_progress_bar = True, enable_model_summary = True,
                 deterministic = True, num_sanity_val_steps=1)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
trainer.fit(model)
# Out:
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Validation - Loss: 0.65, Accuracy: 0.62
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.24, Accuracy: 0.94
# Epoch 0 - Loss: 0.32, Accuracy: 0.89
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.16, Accuracy: 0.93
# Epoch 1 - Loss: 0.21, Accuracy: 0.93
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.09, Accuracy: 0.95
# Epoch 2 - Loss: 0.14, Accuracy: 0.95
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.13, Accuracy: 0.95
# Epoch 3 - Loss: 0.06, Accuracy: 0.98
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.06, Accuracy: 0.98
# Epoch 4 - Loss: 0.03, Accuracy: 0.99
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.06, Accuracy: 0.98
# Epoch 5 - Loss: 0.01, Accuracy: 0.99
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.05, Accuracy: 0.98
# Epoch 6 - Loss: 0.01, Accuracy: 0.99
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.04, Accuracy: 0.99
# Epoch 7 - Loss: 0.01, Accuracy: 0.99
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.14, Accuracy: 0.98
# Epoch 8 - Loss: 0.02, Accuracy: 0.99
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.05, Accuracy: 0.99
# Epoch 9 - Loss: 0.09, Accuracy: 0.97

# %% [markdown]
# # Saving

# %%
trainer.save_checkpoint('/kaggle/working/model.ckpt')

# %% [markdown]
# # Loading

# %%
model = dModel.load_from_checkpoint('/content/model.ckpt',model = video_detection_model, batch_size = 8, transform = transform)

# %% [markdown]
# # Results

# %%
val = trainer.validate(model)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation - Loss: 0.02, Accuracy: 1.00
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        avg_val_acc        │            1.0            │
# │       avg_val_loss        │   0.015203813665782195    │
# │          val_acc          │            1.0            │
# │         val_loss          │   0.015203813665782195    │
# └───────────────────────────┴───────────────────────────┘

# %%
trainer.test(model)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99        76
#          1.0       0.99      1.00      0.99        80
#
#     accuracy                           0.99       156
#    macro avg       0.99      0.99      0.99       156
# weighted avg       0.99      0.99      0.99       156
# [{}]

# %% [markdown]
# # Testing on a custom video!

# %%
# https://www.youtube.com/watch?v=Vhhai08TzA8&t=15s First few seconds of this video

# %%
from pytorchvideo.data.encoded_video import EncodedVideo
video = EncodedVideo.from_path('/content/IMG_2624.mp4')

# %%
data = video.get_clip(0,2)
video_data = transform(data)
video_data['video'].shape
# Out:
# torch.Size([3, 20, 256, 256])

# %%
input = video_data['video'].cuda()
input = torch.unsqueeze(input, 0)
input.shape
# Out:
# torch.Size([1, 3, 20, 256, 256])

# %%
model = model.cuda()

# %%
pred = model(input)
pred = pred.detach().cpu().numpy()
print(pred)
# Out:
# [[4.305897]]

# %%
pred = np.where(pred>0.5, 1, 0)
if pred == 1:
  print('Violence Detected')
else:
  print('Everything is good!')
# Out:
# Violence Detected

# %%
pred = model(input)
#pred = pred.detach().cpu().numpy()
print(pred.sigmoid())
# Out:
# tensor([[0.9970]], device='cuda:0', grad_fn=<SigmoidBackward0>)

# %% [markdown]
# :)
# Recognition:
# Also, much thanks to Talha Anwar's repo I took help from him but tried to understand myself as well!
#
# [Repo](https://github.com/talhaanwarch/youtube-tutorials)
